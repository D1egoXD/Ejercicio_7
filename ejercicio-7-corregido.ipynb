# %% [markdown]
# # Ejercicio 7

# %% [markdown]
# ### 7. Deporte. Se entrevistó a 30 personas para que indicaran cuál es su equipo de futbol preferido. Los resultados fueron los siguientes:

# %% [markdown]
# <table>
#
#   <tr>
#     <td>Pumas</td>
#     <td>América</td>
#     <td>Chivas</td>
#     <td>Pumas</td>
#     <td>Chivas</td>
#   </tr>
#
#   <tr>
#     <td>Chivas</td>
#     <td>América</td>
#     <td>Toluca</td>
#     <td>Toluca</td>
#     <td>Pumas</td>
#   </tr>
#
#   <tr>
#     <td>Santos</td>
#     <td>Necaxa</td>
#     <td>América</td>
#     <td>América</td>
#     <td>América</td>
#   </tr>
#
#   <tr>
#     <td>Pumas</td>
#     <td>Santos</td>
#     <td>Pumas</td>
#     <td>Pumas</td>
#     <td>Pumas</td>
#   </tr>
#
#   <tr>
#     <td>América</td>
#     <td>Chivas</td>
#     <td>América</td>
#     <td>Pumas</td>
#     <td>Necaxa</td>
#   </tr>
#
#   <tr>
#     <td>Toluca</td>
#     <td>Chivas</td>
#     <td>América</td>
#     <td>Toluca</td>
#     <td>Santos</td>
#   </tr>
# </table>

# %% [markdown]
# #### a). Construye la distribución de frecuencias correspondiente.

# %% [markdown]
# <table>
#   <tr>
#     <th>Equipo</th>
#     <th>Frecuencia Absoluta</th>
#     <th>Frecuencia Relativa</th>
#   </tr>
#   <tr>
#     <td>Pumas</td>
#     <td>8</td>
#     <td>0.2667</td>
#   </tr>
#   <tr>
#     <td>América</td>
#     <td>8</td>
#     <td>0.2667</td>
#   </tr>
#   <tr>
#     <td>Chivas</td>
#     <td>5</td>
#     <td>0.1587</td>
#   </tr>
#   <tr>
#     <td>Toluca</td>
#     <td>4</td>
#     <td>0.1333</td>
#   </tr>
#   <tr>
#     <td>Santos</td>
#     <td>3</td>
#     <td>0.1000</td>
#   </tr>
#   <tr>
#     <td>Necaxa</td>
#     <td>2</td>
#     <td>0.0667</td>
#   </tr>
# </table>

# %%
import matplotlib.pyplot as plt

print("setup terminado")
# Out:
# setup terminado

# %% [markdown]
# #### b). Construye un diagrama de barras y uno circular.

# %% [markdown]
# ## Diagrama de Barras

# %%
plt.figure(figsize = (12, 6)) # (ancho, largo) de la grafica

marcas_clase = [1, 2, 3, 4, 5, 6] # datos del eje x
frecuencia = [8, 8, 5, 4, 3, 2] # datos del eje y
marcas_texto = ["Pumas", "América", "Chivas", "Toluca", "Santos", "Necaxa"]

# Diagramas de Barras con:
# - barras ajestadas al 80% (height = 0.8)
# - contorno negro (edgecolor = k)
plt.barh(marcas_clase, frecuencia, 
        height = 0.8, edgecolor = "k", 
        color = ["#ECA520", "#FCF906", "#E74C3C", "#5AB4D4", "#2ABF10", "#BB89EA"]) 

plt.gca().invert_yaxis() # Invertir el sentido del eje y
plt.yticks(marcas_clase, marcas_texto, fontsize = 15)
plt.xlabel("Preferencias de Equipos", fontsize = 25) # etiqueta del eje x
plt.ylabel("Equipos ", fontsize = 25) # etiqueta del eje y
plt.title("Equipos de futbol del la liga MX", fontsize = 40) # titulo de la grafica
plt.grid() # se activa la cuadricula
plt.show() # se muestra el grafico en pantalla

# %% [markdown]
# ## Diagrama de Pastel

# %%
datos = [0.2667, 0.2667, 0.1587, 0.1333, 0.1000, 0.0667]
separaciones = [0, 0, 0, 0, 0, 0]

plt.pie(datos,
       explode = separaciones,
       labels = ["Pumas","America", "Chivas", "Toluca", "Santos", "Necaxa"],
       colors = ["#ECA520", "#FCF906", "#E74C3C", "#5AB4D4", "#2ABF10", "#BB89EA"],
       autopct = "%0.01f%%",
       pctdistance = 0.8,
       counterclock = False,
       startangle = 90)
plt.show()

# %% [markdown]
# #### C). Discute con tus compañeros la información que se desprende de las gráficas anteriores.
